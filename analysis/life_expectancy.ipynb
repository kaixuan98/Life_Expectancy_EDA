# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 

life = pd.read_csv("../data/life_expectancy_data.csv")
life.columns = life.columns.str.strip() # remove white space of data header
life.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
# check of missing values
life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# All predicting variables was then divided into several broad categories:​
#     - Immunization related factors: Hepatitis B, Measles, Polio, Diphtheria
#     - Mortality factors: Alcohol, BMI, thinness 1-19 years, thinness 5-9 years, HIV/AIDS
#     - Economical factors (country effort):Status, Percentage expenditure, total expenditure GDP, population
#     - Social factors(personal effort/surroundings): Schooling, Country, Income composition of resources
# Outcome: Life Expectancy, Infant Deaths, Under-five deaths
#
# 1. We would do the prediction based on immunization related factors.
#     - Hepatitis B in %
#     - Polio in %
#     - Diphtheria in %
#
# 2. Prediction based on social factors
#     - Schooling
#     - Country
#     - Income composition of resources

# %% [markdown]
# ## Immunization Factors

# %%
new_life = life.copy()
new_columns = ["Hepatitis B" , "Polio" , "Diphtheria", "Measles", "Life expectancy" , "Country" , "Year", "Population"]
new_life = new_life.drop([c for c in new_life.columns if c not in new_columns], axis='columns')
new_life.head()
# Out:
#        Country  Year  Life expectancy  Hepatitis B  Measles  Polio  \
# 0  Afghanistan  2015             65.0         65.0     1154    6.0
# 1  Afghanistan  2014             59.9         62.0      492   58.0
# 2  Afghanistan  2013             59.9         64.0      430   62.0
# 3  Afghanistan  2012             59.5         67.0     2787   67.0
# 4  Afghanistan  2011             59.2         68.0     3013   68.0
#
#    Diphtheria  Population
# 0        65.0  33736494.0
# 1        62.0    327582.0
# 2        64.0  31731688.0
# 3        67.0   3696958.0
# 4        68.0   2978599.0

# %%
new_life.isnull().sum()
# Out:
# Country              0
# Year                 0
# Life expectancy     10
# Hepatitis B        553
# Measles              0
# Polio               19
# Diphtheria          19
# Population         652
# dtype: int64

# %%
# check null data for life expectancy 
null_data = new_life[new_life["Life expectancy"].isnull()]
null_data
# Out:
#                     Country  Year  Life expectancy  Hepatitis B  Measles  \
# 624            Cook Islands  2013              NaN         98.0        0
# 769                Dominica  2013              NaN         96.0        0
# 1650       Marshall Islands  2013              NaN          8.0        0
# 1715                 Monaco  2013              NaN         99.0        0
# 1812                  Nauru  2013              NaN         87.0        0
# 1909                   Niue  2013              NaN         99.0        0
# 1958                  Palau  2013              NaN         99.0        0
# 2167  Saint Kitts and Nevis  2013              NaN         97.0        0
# 2216             San Marino  2013              NaN         69.0        0
# 2713                 Tuvalu  2013              NaN          9.0        0
#
#       Polio  Diphtheria  Population
# 624    98.0        98.0         NaN
# 769    96.0        96.0         NaN
# 1650   79.0        79.0         NaN
# 1715   99.0        99.0         NaN
# 1812   87.0        87.0         NaN
# 1909   99.0        99.0         NaN
# 1958   99.0        99.0       292.0
# 2167   96.0        96.0         NaN
# 2216   69.0        69.0         NaN
# 2713    9.0         9.0      1819.0

# %%
# check null data fro Polio
null_data = new_life[new_life["Polio"].isnull()]
null_data
# Out:
#           Country  Year  Life expectancy  Hepatitis B  Measles  Polio  \
# 1742   Montenegro  2005             73.6          NaN        0    NaN
# 1743   Montenegro  2004             73.5          NaN        0    NaN
# 1744   Montenegro  2003             73.5          NaN        0    NaN
# 1745   Montenegro  2002             73.4          NaN        0    NaN
# 1746   Montenegro  2001             73.3          NaN        0    NaN
# 1747   Montenegro  2000             73.0          NaN        0    NaN
# 2414  South Sudan  2010             55.0          NaN        0    NaN
# 2415  South Sudan  2009             54.3          NaN        0    NaN
# 2416  South Sudan  2008             53.6          NaN        0    NaN
# 2417  South Sudan  2007             53.1          NaN        0    NaN
# 2418  South Sudan  2006             52.5          NaN        0    NaN
# 2419  South Sudan  2005             51.9          NaN        0    NaN
# 2420  South Sudan  2004             51.4          NaN        0    NaN
# 2421  South Sudan  2003             58.0          NaN        0    NaN
# 2422  South Sudan  2002             52.0          NaN        0    NaN
# 2423  South Sudan  2001             49.6          NaN        0    NaN
# 2424  South Sudan  2000             48.9          NaN        0    NaN
# 2615  Timor-Leste  2001             59.4          NaN        0    NaN
# 2616  Timor-Leste  2000             58.7          NaN        0    NaN
#
#       Diphtheria  Population
# 1742         NaN    614261.0
# 1743         NaN    613353.0
# 1744         NaN    612267.0
# 1745         NaN     69828.0
# 1746         NaN     67389.0
# 1747         NaN      6495.0
# 2414         NaN    167192.0
# 2415         NaN    967667.0
# 2416         NaN   9263136.0
# 2417         NaN     88568.0
# 2418         NaN   8468152.0
# 2419         NaN    818877.0
# 2420         NaN   7787655.0
# 2421         NaN    751642.0
# 2422         NaN   7237276.0
# 2423         NaN   6974442.0
# 2424         NaN     67656.0
# 2615         NaN    892531.0
# 2616         NaN     87167.0

# %%
# check null data for Diphtheria
null_data = new_life[new_life["Diphtheria"].isnull()]
null_data
# Out:
#           Country  Year  Life expectancy  Hepatitis B  Measles  Polio  \
# 1742   Montenegro  2005             73.6          NaN        0    NaN
# 1743   Montenegro  2004             73.5          NaN        0    NaN
# 1744   Montenegro  2003             73.5          NaN        0    NaN
# 1745   Montenegro  2002             73.4          NaN        0    NaN
# 1746   Montenegro  2001             73.3          NaN        0    NaN
# 1747   Montenegro  2000             73.0          NaN        0    NaN
# 2414  South Sudan  2010             55.0          NaN        0    NaN
# 2415  South Sudan  2009             54.3          NaN        0    NaN
# 2416  South Sudan  2008             53.6          NaN        0    NaN
# 2417  South Sudan  2007             53.1          NaN        0    NaN
# 2418  South Sudan  2006             52.5          NaN        0    NaN
# 2419  South Sudan  2005             51.9          NaN        0    NaN
# 2420  South Sudan  2004             51.4          NaN        0    NaN
# 2421  South Sudan  2003             58.0          NaN        0    NaN
# 2422  South Sudan  2002             52.0          NaN        0    NaN
# 2423  South Sudan  2001             49.6          NaN        0    NaN
# 2424  South Sudan  2000             48.9          NaN        0    NaN
# 2615  Timor-Leste  2001             59.4          NaN        0    NaN
# 2616  Timor-Leste  2000             58.7          NaN        0    NaN
#
#       Diphtheria  Population
# 1742         NaN    614261.0
# 1743         NaN    613353.0
# 1744         NaN    612267.0
# 1745         NaN     69828.0
# 1746         NaN     67389.0
# 1747         NaN      6495.0
# 2414         NaN    167192.0
# 2415         NaN    967667.0
# 2416         NaN   9263136.0
# 2417         NaN     88568.0
# 2418         NaN   8468152.0
# 2419         NaN    818877.0
# 2420         NaN   7787655.0
# 2421         NaN    751642.0
# 2422         NaN   7237276.0
# 2423         NaN   6974442.0
# 2424         NaN     67656.0
# 2615         NaN    892531.0
# 2616         NaN     87167.0

# %%
# only get specific year data 
new_life_2015 = new_life[new_life["Year"] == 2015]
new_life_2015
# Out:
#                                  Country  Year  Life expectancy  Hepatitis B  \
# 0                            Afghanistan  2015             65.0         65.0
# 16                               Albania  2015             77.8         99.0
# 32                               Algeria  2015             75.6         95.0
# 48                                Angola  2015             52.4         64.0
# 64                   Antigua and Barbuda  2015             76.4         99.0
# ...                                  ...   ...              ...          ...
# 2858  Venezuela (Bolivarian Republic of)  2015             74.1         87.0
# 2874                            Viet Nam  2015             76.0         97.0
# 2890                               Yemen  2015             65.7         69.0
# 2906                              Zambia  2015             61.8          9.0
# 2922                            Zimbabwe  2015             67.0         87.0
#
#       Measles  Polio  Diphtheria  Population
# 0        1154    6.0        65.0  33736494.0
# 16          0   99.0        99.0     28873.0
# 32         63   95.0        95.0  39871528.0
# 48        118    7.0        64.0   2785935.0
# 64          0   86.0        99.0         NaN
# ...       ...    ...         ...         ...
# 2858        0   87.0        87.0         NaN
# 2874      256   97.0        97.0         NaN
# 2890      468   63.0        69.0         NaN
# 2906        9    9.0         9.0    161587.0
# 2922        0   88.0        87.0  15777451.0
#
# [183 rows x 8 columns]

# %%
new_life_2015.isnull().sum()
# Out:
# Country             0
# Year                0
# Life expectancy     0
# Hepatitis B         9
# Measles             0
# Polio               0
# Diphtheria          0
# Population         41
# dtype: int64

# %%
# replacing NaN in Hep3 to 0 
# new_life_2015 = null_data[new_life_2015["Hepatitis B"].isnull()]
new_life_2015["Hepatitis B"] = new_life_2015["Hepatitis B"].fillna(0)
print(new_life_2015.isnull().sum())
new_life_2015
# Out:
# Country             0
# Year                0
# Life expectancy     0
# Hepatitis B         0
# Measles             0
# Polio               0
# Diphtheria          0
# Population         41
# dtype: int64
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                  Country  Year  Life expectancy  Hepatitis B  \
# 0                            Afghanistan  2015             65.0         65.0
# 16                               Albania  2015             77.8         99.0
# 32                               Algeria  2015             75.6         95.0
# 48                                Angola  2015             52.4         64.0
# 64                   Antigua and Barbuda  2015             76.4         99.0
# ...                                  ...   ...              ...          ...
# 2858  Venezuela (Bolivarian Republic of)  2015             74.1         87.0
# 2874                            Viet Nam  2015             76.0         97.0
# 2890                               Yemen  2015             65.7         69.0
# 2906                              Zambia  2015             61.8          9.0
# 2922                            Zimbabwe  2015             67.0         87.0
#
#       Measles  Polio  Diphtheria  Population
# 0        1154    6.0        65.0  33736494.0
# 16          0   99.0        99.0     28873.0
# 32         63   95.0        95.0  39871528.0
# 48        118    7.0        64.0   2785935.0
# 64          0   86.0        99.0         NaN
# ...       ...    ...         ...         ...
# 2858        0   87.0        87.0         NaN
# 2874      256   97.0        97.0         NaN
# 2890      468   63.0        69.0         NaN
# 2906        9    9.0         9.0    161587.0
# 2922        0   88.0        87.0  15777451.0
#
# [183 rows x 8 columns]

# %%
null_data = new_life_2015[new_life_2015["Population"].isnull()]
null_data
# Out:
#                                                 Country  Year  \
# 64                                  Antigua and Barbuda  2015
# 160                                             Bahamas  2015
# 176                                             Bahrain  2015
# 208                                            Barbados  2015
# 304                    Bolivia (Plurinational State of)  2015
# 368                                   Brunei Darussalam  2015
# 432                                       Côte d'Ivoire  2015
# 608                                               Congo  2015
# 657                                                Cuba  2015
# 689                                             Czechia  2015
# 705               Democratic People's Republic of Korea  2015
# 721                    Democratic Republic of the Congo  2015
# 802                                               Egypt  2015
# 850                                             Eritrea  2015
# 962                                              Gambia  2015
# 1042                                            Grenada  2015
# 1218                         Iran (Islamic Republic of)  2015
# 1394                                             Kuwait  2015
# 1410                                         Kyrgyzstan  2015
# 1426                   Lao People's Democratic Republic  2015
# 1506                                              Libya  2015
# 1699                   Micronesia (Federated States of)  2015
# 1845                                        New Zealand  2015
# 1926                                               Oman  2015
# 2071                                              Qatar  2015
# 2087                                  Republic of Korea  2015
# 2103                                Republic of Moldova  2015
# 2168                                        Saint Lucia  2015
# 2184                   Saint Vincent and the Grenadines  2015
# 2233                                       Saudi Arabia  2015
# 2313                                          Singapore  2015
# 2329                                           Slovakia  2015
# 2377                                            Somalia  2015
# 2585          The former Yugoslav republic of Macedonia  2015
# 2746                               United Arab Emirates  2015
# 2762  United Kingdom of Great Britain and Northern I...  2015
# 2778                        United Republic of Tanzania  2015
# 2794                           United States of America  2015
# 2858                 Venezuela (Bolivarian Republic of)  2015
# 2874                                           Viet Nam  2015
# 2890                                              Yemen  2015
#
#       Life expectancy  Hepatitis B  Measles  Polio  Diphtheria  Population
# 64               76.4         99.0        0   86.0        99.0         NaN
# 160              76.1         95.0        0   95.0        95.0         NaN
# 176              76.9         98.0        0   98.0        98.0         NaN
# 208              75.5         97.0        0   97.0        97.0         NaN
# 304              77.0         99.0        0   99.0        99.0         NaN
# 368              77.7         99.0        4   99.0        99.0         NaN
# 432              53.3         83.0       65   81.0        83.0         NaN
# 608              64.7          8.0     1359    8.0         8.0         NaN
# 657              79.1         99.0        0   99.0        99.0         NaN
# 689              78.8         97.0        9   97.0        97.0         NaN
# 705              76.0         96.0        0   99.0        96.0         NaN
# 721              59.8         81.0     5020   78.0        81.0         NaN
# 802              79.0         93.0     5432   93.0        93.0         NaN
# 850              64.7         95.0      198   95.0        95.0         NaN
# 962              61.1         97.0       71   96.0        97.0         NaN
# 1042             73.6         92.0        0   99.0        92.0         NaN
# 1218             75.5         98.0      615   98.0        98.0         NaN
# 1394             74.7         99.0       18   99.0        99.0         NaN
# 1410             71.1         97.0    17779   97.0        97.0         NaN
# 1426             65.7         89.0       56   89.0        89.0         NaN
# 1506             72.7         97.0       82   97.0        97.0         NaN
# 1699             69.4         78.0        0   71.0        72.0         NaN
# 1845             81.6         92.0       10   92.0        92.0         NaN
# 1926             76.6         99.0        0   99.0        99.0         NaN
# 2071             78.2         99.0       18   99.0        99.0         NaN
# 2087             82.3         98.0        7   98.0        98.0         NaN
# 2103             72.1         88.0        0   88.0        87.0         NaN
# 2168             75.2         99.0        0   99.0        99.0         NaN
# 2184             73.2         98.0        0   97.0        98.0         NaN
# 2233             74.5         98.0      219   97.0        98.0         NaN
# 2313             83.1         96.0        0   96.0        96.0         NaN
# 2329             76.7         96.0        1   96.0        96.0         NaN
# 2377             55.0         42.0     7497   47.0        42.0         NaN
# 2585             75.7         92.0        1   92.0        91.0         NaN
# 2746             77.1         99.0      347   99.0        99.0         NaN
# 2762             81.2          0.0       91   96.0        96.0         NaN
# 2778             61.8         98.0       30   96.0        98.0         NaN
# 2794             79.3         92.0      188   93.0        95.0         NaN
# 2858             74.1         87.0        0   87.0        87.0         NaN
# 2874             76.0         97.0      256   97.0        97.0         NaN
# 2890             65.7         69.0      468   63.0        69.0         NaN

# %%
pop_2015 = pd.read_csv("../data/pop-2015.csv")
pop_2015 = pop_2015.rename(columns={'2015 [YR2015]':'Population' , 'Country Name': 'Country'})
pop_2015.head()
# Out:
#          Series Name  Series Code         Country Country Code Population
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG   34413603
# 1  Population, total  SP.POP.TOTL         Albania          ALB    2880703
# 2  Population, total  SP.POP.TOTL         Algeria          DZA   39728020
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM      55806
# 4  Population, total  SP.POP.TOTL         Andorra          AND      77993

# %%
merged = pd.merge(new_life_2015, pop_2015, on="Country")
merged.isnull().sum()
# Out:
# Country             0
# Year                0
# Life expectancy     0
# Hepatitis B         0
# Measles             0
# Polio               0
# Diphtheria          0
# Population_x       16
# Series Name         0
# Series Code         0
# Country Code        0
# Population_y        0
# dtype: int64

# %%
null_data = merged[merged["Population_x"].isnull()]
null_data
# Out:
#                   Country  Year  Life expectancy  Hepatitis B  Measles  Polio  \
# 4     Antigua and Barbuda  2015             76.4         99.0        0   86.0
# 10                Bahrain  2015             76.9         98.0        0   98.0
# 12               Barbados  2015             75.5         97.0        0   97.0
# 21      Brunei Darussalam  2015             77.7         99.0        4   99.0
# 37                   Cuba  2015             79.1         99.0        0   99.0
# 45                Eritrea  2015             64.7         95.0      198   95.0
# 56                Grenada  2015             73.6         92.0        0   99.0
# 77                 Kuwait  2015             74.7         99.0       18   99.0
# 82                  Libya  2015             72.7         97.0       82   97.0
# 102           New Zealand  2015             81.6         92.0       10   92.0
# 107                  Oman  2015             76.6         99.0        0   99.0
# 116                 Qatar  2015             78.2         99.0       18   99.0
# 122          Saudi Arabia  2015             74.5         98.0      219   97.0
# 127             Singapore  2015             83.1         96.0        0   96.0
# 130               Somalia  2015             55.0         42.0     7497   47.0
# 151  United Arab Emirates  2015             77.1         99.0      347   99.0
#
#      Diphtheria  Population_x        Series Name  Series Code Country Code  \
# 4          99.0           NaN  Population, total  SP.POP.TOTL          ATG
# 10         98.0           NaN  Population, total  SP.POP.TOTL          BHR
# 12         97.0           NaN  Population, total  SP.POP.TOTL          BRB
# 21         99.0           NaN  Population, total  SP.POP.TOTL          BRN
# 37         99.0           NaN  Population, total  SP.POP.TOTL          CUB
# 45         95.0           NaN  Population, total  SP.POP.TOTL          ERI
# 56         92.0           NaN  Population, total  SP.POP.TOTL          GRD
# 77         99.0           NaN  Population, total  SP.POP.TOTL          KWT
# 82         97.0           NaN  Population, total  SP.POP.TOTL          LBY
# 102        92.0           NaN  Population, total  SP.POP.TOTL          NZL
# 107        99.0           NaN  Population, total  SP.POP.TOTL          OMN
# 116        99.0           NaN  Population, total  SP.POP.TOTL          QAT
# 122        98.0           NaN  Population, total  SP.POP.TOTL          SAU
# 127        96.0           NaN  Population, total  SP.POP.TOTL          SGP
# 130        42.0           NaN  Population, total  SP.POP.TOTL          SOM
# 151        99.0           NaN  Population, total  SP.POP.TOTL          ARE
#
#     Population_y
# 4          93571
# 10       1371853
# 12        285327
# 21        414914
# 37      11324777
# 45            ..
# 56        109603
# 77       3835588
# 82       6418315
# 102      4609400
# 107      4267341
# 116      2565708
# 122     31717676
# 127      5535002
# 130     13797204
# 151      9262896

# %%
# drop columns that we do not need from pop_2015
new_life_2015 = merged.drop(['Population_x', 'Series Name', 'Series Code'], 1)
new_life_2015 = new_life_2015.rename(columns={'Population_y':'Population'})
# new_life_2015['Population'] = new_life_2015['Population'].apply(lambda x : float(x))
new_life_2015.head()
# Out:
#                Country  Year  Life expectancy  Hepatitis B  Measles  Polio  \
# 0          Afghanistan  2015             65.0         65.0     1154    6.0
# 1              Albania  2015             77.8         99.0        0   99.0
# 2              Algeria  2015             75.6         95.0       63   95.0
# 3               Angola  2015             52.4         64.0      118    7.0
# 4  Antigua and Barbuda  2015             76.4         99.0        0   86.0
#
#    Diphtheria Country Code Population
# 0        65.0          AFG   34413603
# 1        99.0          ALB    2880703
# 2        95.0          DZA   39728020
# 3        64.0          AGO   27884380
# 4        99.0          ATG      93571

# %%
problem_data = new_life_2015[new_life_2015['Population'] == '..']
new_life_2015[new_life_2015['Population'] == '..'].replace('..',3214000 )
# Out:
#     Country  Year  Life expectancy  Hepatitis B  Measles  Polio  Diphtheria  \
# 45  Eritrea  2015             64.7         95.0      198   95.0        95.0
#
#    Country Code  Population
# 45          ERI     3214000

# %%
new_life_2015.loc[new_life_2015['Population'] == "..", 'Population'] = 3214000 
problem_data = new_life_2015[new_life_2015['Population'] == '..']
problem_data
# Out:
# Empty DataFrame
# Columns: [Country, Year, Life expectancy, Hepatitis B, Measles, Polio, Diphtheria, Country Code, Population]
# Index: []

# %%
# adding measles immunization to the dataset ( dataset from WorldBank )
measles_2015 = pd.read_csv("../data/measles_2015.csv")
measles_2015 = measles_2015.rename(columns={'2015 [YR2015]':'Measles Immunity' , 'Country Name': 'Country'})
merged = pd.merge(new_life_2015, measles_2015, on="Country")
merged.isnull().sum()
merged.head()
# Out:
#                Country  Year  Life expectancy  Hepatitis B  Measles  Polio  \
# 0          Afghanistan  2015             65.0         65.0     1154    6.0
# 1              Albania  2015             77.8         99.0        0   99.0
# 2              Algeria  2015             75.6         95.0       63   95.0
# 3               Angola  2015             52.4         64.0      118    7.0
# 4  Antigua and Barbuda  2015             76.4         99.0        0   86.0
#
#    Diphtheria Country Code_x Population  \
# 0        65.0            AFG   34413603
# 1        99.0            ALB    2880703
# 2        95.0            DZA   39728020
# 3        64.0            AGO   27884380
# 4        99.0            ATG      93571
#
#                                          Series Name  Series Code  \
# 0  Immunization, measles (% of children ages 12-2...  SH.IMM.MEAS
# 1  Immunization, measles (% of children ages 12-2...  SH.IMM.MEAS
# 2  Immunization, measles (% of children ages 12-2...  SH.IMM.MEAS
# 3  Immunization, measles (% of children ages 12-2...  SH.IMM.MEAS
# 4  Immunization, measles (% of children ages 12-2...  SH.IMM.MEAS
#
#   Country Code_y Measles Immunity
# 0            AFG               63
# 1            ALB               97
# 2            DZA               95
# 3            AGO               51
# 4            ATG               91

# %%
# drop columns that we do not need from pop_2015
new_life_2015 = merged.drop(['Series Name', 'Series Code', 'Country Code_x' , 'Measles', 'Year' , 'Population'], 1)
new_life_2015.head()
# new_life.dtypes
# Out:
#                Country  Life expectancy  Hepatitis B  Polio  Diphtheria  \
# 0          Afghanistan             65.0         65.0    6.0        65.0
# 1              Albania             77.8         99.0   99.0        99.0
# 2              Algeria             75.6         95.0   95.0        95.0
# 3               Angola             52.4         64.0    7.0        64.0
# 4  Antigua and Barbuda             76.4         99.0   86.0        99.0
#
#   Country Code_y Measles Immunity
# 0            AFG               63
# 1            ALB               97
# 2            DZA               95
# 3            AGO               51
# 4            ATG               91

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler

new_life_2015['Country'] = LabelEncoder().fit_transform(new_life_2015['Country'])
new_life_2015.head()
# Out:
#    Country  Life expectancy  Hepatitis B  Polio  Diphtheria Country Code_y  \
# 0        0             65.0         65.0    6.0        65.0            AFG
# 1        1             77.8         99.0   99.0        99.0            ALB
# 2        2             75.6         95.0   95.0        95.0            DZA
# 3        3             52.4         64.0    7.0        64.0            AGO
# 4        4             76.4         99.0   86.0        99.0            ATG
#
#   Measles Immunity
# 0               63
# 1               97
# 2               95
# 3               51
# 4               91

# %%
# building model
selected_features = ['Country', 'Hepatitis B' , 'Polio' , 'Diphtheria', 'Measles Immunity']

X = new_life_2015[selected_features]
y = new_life_2015['Life expectancy']

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.2, random_state=0)

# %%
# training model (Immunizing factors)
from sklearn.metrics import accuracy_score

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

accuracy_score = model.score(X_train, y_train)
print('Model Accuracy(Immunizing factors): ', accuracy_score )
# Out:
# Model Accuracy(Immunizing factors):  0.5701757851753699

# %% [markdown]
# ## Social Factor

# %%
new_life = life.copy()
new_columns = ["Alcohol" , "Schooling", "Income composition of resources", "Life expectancy" , "Country" , "Year", "Population"]
new_life = new_life.drop([c for c in new_life.columns if c not in new_columns], axis='columns')
new_life_2015 = new_life[new_life["Year"] == 2015]
new_life_2015
# Out:
#                                  Country  Year  Life expectancy  Alcohol  \
# 0                            Afghanistan  2015             65.0     0.01
# 16                               Albania  2015             77.8     4.60
# 32                               Algeria  2015             75.6      NaN
# 48                                Angola  2015             52.4      NaN
# 64                   Antigua and Barbuda  2015             76.4      NaN
# ...                                  ...   ...              ...      ...
# 2858  Venezuela (Bolivarian Republic of)  2015             74.1      NaN
# 2874                            Viet Nam  2015             76.0      NaN
# 2890                               Yemen  2015             65.7      NaN
# 2906                              Zambia  2015             61.8      NaN
# 2922                            Zimbabwe  2015             67.0      NaN
#
#       Population  Income composition of resources  Schooling
# 0     33736494.0                            0.479       10.1
# 16       28873.0                            0.762       14.2
# 32    39871528.0                            0.743       14.4
# 48     2785935.0                            0.531       11.4
# 64           NaN                            0.784       13.9
# ...          ...                              ...        ...
# 2858         NaN                            0.769       14.3
# 2874         NaN                            0.678       12.6
# 2890         NaN                            0.499        9.0
# 2906    161587.0                            0.576       12.5
# 2922  15777451.0                            0.507       10.3
#
# [183 rows x 7 columns]

# %%
merged = pd.merge(new_life_2015, pop_2015, on="Country")
merged
# Out:
#                  Country  Year  Life expectancy  Alcohol  Population_x  \
# 0            Afghanistan  2015             65.0     0.01    33736494.0
# 1                Albania  2015             77.8     4.60       28873.0
# 2                Algeria  2015             75.6      NaN    39871528.0
# 3                 Angola  2015             52.4      NaN     2785935.0
# 4    Antigua and Barbuda  2015             76.4      NaN           NaN
# ..                   ...   ...              ...      ...           ...
# 152              Uruguay  2015             77.0      NaN     3431552.0
# 153           Uzbekistan  2015             69.4      NaN      312989.0
# 154              Vanuatu  2015             72.0      NaN       26463.0
# 155               Zambia  2015             61.8      NaN      161587.0
# 156             Zimbabwe  2015             67.0      NaN    15777451.0
#
#      Income composition of resources  Schooling        Series Name  \
# 0                              0.479       10.1  Population, total
# 1                              0.762       14.2  Population, total
# 2                              0.743       14.4  Population, total
# 3                              0.531       11.4  Population, total
# 4                              0.784       13.9  Population, total
# ..                               ...        ...                ...
# 152                            0.794       15.5  Population, total
# 153                            0.697       12.1  Population, total
# 154                            0.598       10.8  Population, total
# 155                            0.576       12.5  Population, total
# 156                            0.507       10.3  Population, total
#
#      Series Code Country Code Population_y
# 0    SP.POP.TOTL          AFG     34413603
# 1    SP.POP.TOTL          ALB      2880703
# 2    SP.POP.TOTL          DZA     39728020
# 3    SP.POP.TOTL          AGO     27884380
# 4    SP.POP.TOTL          ATG        93571
# ..           ...          ...          ...
# 152  SP.POP.TOTL          URY      3412013
# 153  SP.POP.TOTL          UZB     31298900
# 154  SP.POP.TOTL          VUT       271128
# 155  SP.POP.TOTL          ZMB     15879370
# 156  SP.POP.TOTL          ZWE     13814642
#
# [157 rows x 11 columns]

# %%
new_life_2015 = merged.drop(['Population_x', 'Series Name', 'Series Code', 'Population_y'], 1)
new_life_2015.head()
# Out:
#                Country  Year  Life expectancy  Alcohol  \
# 0          Afghanistan  2015             65.0     0.01
# 1              Albania  2015             77.8     4.60
# 2              Algeria  2015             75.6      NaN
# 3               Angola  2015             52.4      NaN
# 4  Antigua and Barbuda  2015             76.4      NaN
#
#    Income composition of resources  Schooling Country Code
# 0                            0.479       10.1          AFG
# 1                            0.762       14.2          ALB
# 2                            0.743       14.4          DZA
# 3                            0.531       11.4          AGO
# 4                            0.784       13.9          ATG

# %%
new_life_2015.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Life expectancy                      0
# Alcohol                            152
# Income composition of resources      1
# Schooling                            1
# Country Code                         0
# dtype: int64

# %%
alcohol_consumption = pd.read_csv('../data/alcohol_consumption.csv')
alcohol_consumption.head()
alcohol_2015 = alcohol_consumption.rename(columns={'2015 [YR2015]':'Alcohol Consumption' , 'Country Name': 'Country'})
merged = pd.merge(new_life_2015, alcohol_2015, on="Country Code")
merged.isnull().sum()
new_life_2015 = merged.drop(['Series Name', 'Series Code', 'Year'], 1)
new_life_2015.head()
# Out:
#              Country_x  Life expectancy  Alcohol  \
# 0          Afghanistan             65.0     0.01
# 1              Albania             77.8     4.60
# 2              Algeria             75.6      NaN
# 3               Angola             52.4      NaN
# 4  Antigua and Barbuda             76.4      NaN
#
#    Income composition of resources  Schooling Country Code  \
# 0                            0.479       10.1          AFG
# 1                            0.762       14.2          ALB
# 2                            0.743       14.4          DZA
# 3                            0.531       11.4          AGO
# 4                            0.784       13.9          ATG
#
#              Country_y Alcohol Consumption
# 0          Afghanistan                0.21
# 1              Albania                6.74
# 2              Algeria                0.93
# 3               Angola                7.96
# 4  Antigua and Barbuda                5.89

# %%
new_life_2015.isnull().sum()
# Out:
# Country_x                            0
# Life expectancy                      0
# Alcohol                            152
# Income composition of resources      1
# Schooling                            1
# Country Code                         0
# Country_y                            0
# Alcohol Consumption                  0
# dtype: int64

# %%
new_life_2015 = new_life_2015.drop(['Alcohol', 'Country_y'],1)
new_life_2015.isnull().sum()
# Out:
# Country_x                          0
# Life expectancy                    0
# Income composition of resources    1
# Schooling                          1
# Country Code                       0
# Alcohol Consumption                0
# dtype: int64

# %%
# not able to find Somalia data on Schooling and Income composition of resources so removed 
missing_data = new_life_2015[new_life_2015['Schooling'].isnull()]
missing_data
new_life_2015 = new_life_2015.drop(index=130)

# %%
missing_data = new_life_2015[new_life_2015['Alcohol Consumption'] == ".."]
missing_data
new_life_2015 = new_life_2015.drop(index=132)

# %%
# building model
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

selected_features = ['Income composition of resources', 'Schooling', 'Alcohol Consumption']

X = new_life_2015[selected_features]
y = new_life_2015['Life expectancy']

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.2, random_state=0)

# %%
# training model (Social Factor)
from sklearn.metrics import accuracy_score

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

accuracy_score = model.score(X_train, y_train)
print('Model Accuracy(Social Factor): ', accuracy_score )
# Out:
# Model Accuracy(Social Factor):  0.8166200517428115
